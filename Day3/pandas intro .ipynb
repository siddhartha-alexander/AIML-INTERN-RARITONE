# %% [markdown]
# ### Pandas
# Pandas is the primary,open-source Python library used for Data manipulation ,analysis and
# cleaning.It functions similarly to an Excel spreadsheet or an SQL databases table ,
# allowing you to work with large datasets

# %% [markdown]
# import pandas as pd

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.5

# %%
data={'Name':['Siddhartha','Alexander','Damala'],'height':[5.8,5.9,6.0]}
pd.DataFrame(data)
# Out:
#          Name  height
# 0  Siddhartha     5.8
# 1   Alexander     5.9
# 2      Damala     6.0
